# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from glob import glob

adir_data = 'F:/data/cruise_data/saildrone/sss/sss_collocations_8day_nearest_norepeat/'
saildrone_filenames_rss = glob(adir_data+'*arctic_misst*rss*.nc')
print(saildrone_filenames_rss)

saildrone_filenames_jpl = glob(adir_data+'*arctic_misst*jpl*.nc')

plt.rcParams['figure.figsize'] = (15.0, 8.0)
# Out:
# ['F:/data/cruise_data/saildrone/sss/sss_collocations_8day_nearest_norepeat\\saildrone-gen_5-arctic_misst_2019-sd1036-20190514T230000-20191011T183000-1_minutes-v1.1575336154680_RSS8dynorep.nc', 'F:/data/cruise_data/saildrone/sss/sss_collocations_8day_nearest_norepeat\\saildrone-gen_5-arctic_misst_2019-sd1037-20190514T230000-20191011T183000-1_minutes-v1.1575487464625_RSS8dynorep.nc']

# %%
ds=[]
for iusv in range(2):
    fname=saildrone_filenames_rss[iusv]
    ds_usv=xr.open_dataset(fname)#.swap_dims({'ob':'time'})#.isel(trajectory=0).swap_dims({'obs':'time'})
    ds_usv.close()
    ds_usv=ds_usv.where(ds_usv.sat_sss_smap>10)
    ds.append(ds_usv)
ds_saildrone_rss = xr.concat(ds,dim='trajectory')
ds=[]
for iusv in range(2):
    fname=saildrone_filenames_jpl[iusv]
    ds_usv=xr.open_dataset(fname)#.swap_dims({'ob':'time'})#.isel(trajectory=0).swap_dims({'obs':'time'})
    ds_usv.close()
    ds_usv=ds_usv.where(ds_usv.sat_smap_sss>10)
    ds.append(ds_usv)
ds_saildrone_jpl = xr.concat(ds,dim='trajectory')

# %%
ds_saildrone_jpl
# Out:
# <xarray.Dataset>
# Dimensions:                       (ob: 794, trajectory: 2)
# Coordinates:
#   * ob                            (ob) int64 0 1 2 3 4 5 ... 789 790 791 792 793
#   * trajectory                    (trajectory) object '1036' '1037'
# Data variables:
#     SOG_MEAN                      (trajectory, ob) float64 0.661 1.334 ... nan
#     COG_MEAN                      (trajectory, ob) float64 176.0 37.02 ... nan
#     HDG_MEAN                      (trajectory, ob) float64 119.4 44.82 ... nan
#     ROLL_MEAN                     (trajectory, ob) float64 0.6791 3.457 ... nan
#     PITCH_MEAN                    (trajectory, ob) float64 -0.8179 ... nan
#     UWND_MEAN                     (trajectory, ob) float64 1.362 5.539 ... nan
#     VWND_MEAN                     (trajectory, ob) float64 -2.911 -4.262 ... nan
#     WWND_MEAN                     (trajectory, ob) float64 -0.04315 ... nan
#     GUST_WND_MEAN                 (trajectory, ob) float64 4.369 8.038 ... nan
#     WIND_MEASUREMENT_HEIGHT_MEAN  (trajectory, ob) float64 4.978 4.957 ... nan
#     TEMP_AIR_MEAN                 (trajectory, ob) float64 5.176 4.806 ... nan
#     RH_MEAN                       (trajectory, ob) float64 75.52 76.45 ... nan
#     BARO_PRES_MEAN                (trajectory, ob) float64 1.006e+03 ... nan
#     PAR_AIR_MEAN                  (trajectory, ob) float64 335.5 ... nan
#     TEMP_CTD_MEAN                 (trajectory, ob) float64 6.828 6.676 ... nan
#     TEMP_CTD_STDDEV               (trajectory, ob) float64 0.001775 ... nan
#     SAL_CTD_MEAN                  (trajectory, ob) float64 32.32 32.36 ... nan
#     TEMP_RBR_MEAN                 (trajectory, ob) float64 6.827 6.678 ... nan
#     SAL_RBR_MEAN                  (trajectory, ob) float64 32.14 32.2 ... nan
#     CHLOR_WETLABS_MEAN            (trajectory, ob) float64 2.661 2.385 ... nan
#     CHLOR_MEAN                    (trajectory, ob) float64 9.103 8.969 ... nan
#     TEMP_O2_RBR_MEAN              (trajectory, ob) float64 1e+05 1e+05 ... nan
#     CDOM_MEAN                     (trajectory, ob) float64 1e+05 1e+05 ... nan
#     sat_smap_sss                  (trajectory, ob) float32 32.52 32.52 ... nan
#     sat_anc_sss                   (trajectory, ob) float32 32.56 32.53 ... nan
#     sat_anc_sst                   (trajectory, ob) float32 279.7 279.7 ... nan
#     sat_smap_spd                  (trajectory, ob) float32 6.805 5.991 ... nan
#     sat_smap_high_spd             (trajectory, ob) float32 7.462 6.747 ... nan
#     sat_weight                    (trajectory, ob) float32 13.73 14.0 ... nan
#     sat_land_fraction             (trajectory, ob) float32 0.001685 ... nan
#     sat_ice_concentration         (trajectory, ob) float32 0.0 0.0 ... nan nan
#     sat_smap_sss_uncertainty      (trajectory, ob) float32 0.8751 0.8374 ... nan
#     sat_lat                       (trajectory, ob) float64 54.26 54.31 ... nan
#     sat_lon                       (trajectory, ob) float64 -166.7 -166.6 ... nan
#     time                          (trajectory, ob) datetime64[ns] 2019-05-16T...
# Attributes:
#     title:                     Arctic NASA MISST 2019 Mission
#     summary:                   Saildrone surface observational data for the N...
#     ncei_template_version:     NCEI_NetCDF_Trajectory_Template_v2.0
#     Conventions:               CF-1.6, ACDD-1.3
#     netcdf_version:            4.6.3
#     featureType:               trajectory
#     cdm_data_type:             Trajectory
#     standard_name_vocabulary:  CF Standard Name Table v58
#     description:               Saildrone NetCDF Format
#     creator_name:              Saildrone
#     platform:                  Saildrone
#     institution:               Saildrone
#     creator_email:             support@saildrone.com
#     creator_url:               https://saildrone.com/
#     date_created:              2019-12-03T01:15:41.913484Z
#     time_coverage_start:       2019-05-14T23:00:00.000Z
#     time_coverage_end:         2019-10-11T18:30:00.000Z
#     time_coverage_resolution:  1-minute
#     time_coverage_duration:    P149DT19H30M0S
#     area:                      Bering and Chukchi Seas
#     data_mode:                 delayed-mode
#     drone_id:                  1036
#     id:                        74829
#     naming_authority:          saildrone.com
#     uuid:                      9854504d-6241-4b9c-8964-42c82c95a1cc
#     project:                   NASA Multi-Sensor Improved Sea Surface Tempera...
#     source:                    Saildrone
#     license:                   2019 CC-BY SAILDRONE Inc.  All Rights Reserved...
#     nodc_template_version:     NODC_NetCDF_Trajectory_Template_v2.0
#     wmo_id:                    4803914
#     geospatial_lat_min:        53.8464768
#     geospatial_lat_max:        75.222176
#     geospatial_lat_units:      degrees_north
#     geospatial_lon_min:        -176.2569088
#     geospatial_lon_max:        -147.8197248
#     geospatial_lon_units:      degrees_east
#     history:                   created post-cruise 1/2020
#     product_version:           v01.0
#     keywords:                  Temperature, Salinity, Wind Vectors, Air Tempe...
#     keywords_vocabulary:       NASA/GCMD
#     publisher_name:            Saildrone
#     publisher_url:             www.saildrone.com
#     publisher_email:           support@saildrone.com
#     acknowledgment:            Saildrone. 2019. Saildrone Arctic field campai...
#     processing_level:          Level 2
#     vehicle_id:                sd1036

# %%
plt.scatter(ds_saildrone_rss.time.dt.dayofyear,ds_saildrone_rss.sat_sss_smap,label='RSS') #sat_smap_sss)
plt.scatter(ds_saildrone_jpl.time.dt.dayofyear,ds_saildrone_jpl.sat_smap_sss,c='r',label='JPL') #sat_smap_sss)
plt.grid()
plt.legend()
plt.savefig('f:\sss_fig4.png')
