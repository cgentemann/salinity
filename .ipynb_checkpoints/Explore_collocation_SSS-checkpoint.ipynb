# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
sys.path.append('../saildrone/subroutines/')
import warnings
warnings.simplefilter('ignore') # filter some warning messages
from glob import glob

# %% [markdown]
# # read in collocated files

# %%
data_dir = 'F:/data/cruise_data/saildrone/sss_collocations/'
data_dir = 'F:/data/cruise_data/saildrone/sss_collocations_norepeat/'
filenames = [x for x in glob(data_dir+'*.nc')]
filenames
# Out:
# ['F:/data/cruise_data/saildrone/sss_collocations_norepeat\\PMEL_Arctic_2015_sd126-ALL-1_min-v1rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\PMEL_Arctic_2015_sd128-ALL-1_min-v1rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\PMEL_Arctic_2016_sd126-ALL-1_min-v1rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\PMEL_Arctic_2016_sd128-ALL-1_min-v1rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone-gen_4-baja_2018-sd1002-20180411T180000-20180611T055959-1_minutes-v1rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone-gen_4-shark-2018-sd1001-20180315T000000-20180529T235959-1_minutes-v1.1581626958976rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone-gen_4-shark-2018-sd1004-20180315T000000-20180617T235959-1_minutes-v1.1581627077777rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone-gen_5-1021_atlantic-sd1021-20190525T000000-20191021T235959-1_minutes-v1.1571806429446_(1)rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone-gen_5-arctic_misst_2019-sd1036-20190514T230000-20191011T183000-1_minutes-v1.1575336154680rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone-gen_5-arctic_misst_2019-sd1037-20190514T230000-20191011T183000-1_minutes-v1.1575487464625rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone_arctic_sd1033_2019rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone_arctic_sd1034_2019rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone_arctic_sd1035_2019rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone_arctic_sd1041_2019rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone_tpos_sd1005_2017rssv4_filesave3norep.nc',
#  'F:/data/cruise_data/saildrone/sss_collocations_norepeat\\saildrone_tpos_sd1005_2018rssv4_filesave3norep.nc']

# %%
data_dict={}
for iname,name in enumerate(filenames):
    ds = xr.open_dataset(name)
    ds.close()
    i = name.find('\\')
    sname = name[i+1:-3]
    if iname==0:
        data_dict = {name:ds}
    else:
        data_dict[name]=ds

# %%
fig, axs = plt.subplots(4,4,figsize=(12,12))
ii=0
for iname,name in enumerate(data_dict):
    ii1=int(ii/4)
    ii2=ii-ii1*4
    print(ii,ii1,ii2)
    ds = data_dict[name]
    dif = ds.SAL_CTD_MEAN - ds.smap_SSS
    dif = dif.where((ds.smap_SSS>2) & (ds.smap_SSS<50) & (ds.SAL_CTD_MEAN<50))
    difm = np.nanmean(dif)
    difs = np.nanstd(dif)
    print(iname,"{:.2f}".format(difm),"{:.2f}".format(difs),np.isfinite(dif).sum().data)
    if np.isfinite(difm):
        ax = axs[ii1,ii2]
        ax.plot(ds.SAL_CTD_MEAN)
        ax.plot(ds.smap_SSS)
        ii+=1
# Out:
# 0 0 0
# 0 -0.71 1.85 364
# 1 0 1
# 1 -0.90 1.58 334
# 2 0 2
# 2 -0.08 0.74 306
# 3 0 3
# 3 -0.13 0.76 351
# 4 1 0
# 4 0.23 0.65 173
# 5 1 1
# 5 0.15 0.49 215
# 6 1 2
# 6 -0.01 0.49 298
# 7 1 3
# 7 -0.07 0.85 333
# 8 2 0
# 8 0.16 1.29 582
# 9 2 1
# 9 -0.03 1.73 710
# 10 2 2
# 10 nan nan 0
# 10 2 2
# 11 nan nan 0
# 10 2 2
# 12 nan nan 0
# 10 2 2
# 13 nan nan 0
# 10 2 2
# 14 -0.34 0.47 520
# 11 2 3
# 15 0.03 0.41 206

# %%
plt.plot(ds.SAL_CTD_MEAN)
plt.plot(ds.smap_SSS)

# %%
ds = sv.copy(deep=True)
dif = ds.SAL_CTD_MEAN - ds.smap_SSS
dif = dif.where((ds.smap_SSS>2) & (ds.smap_SSS<50) & (ds.SAL_CTD_MEAN<50))
difm = np.nanmean(dif)
difs = np.nanstd(dif)
difm
# Out:
# nan

# %%
ds=sv
dif = ds.SAL_CTD_MEAN - ds.smap_SSS
dif = dif.where(ds.smap_SSS>50)

# %%
dif
# Out:
# <xarray.DataArray (ob: 640)>
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan])
# Coordinates:
#   * ob       (ob) int64 0 1 2 3 4 5 6 7 8 ... 632 633 634 635 636 637 638 639
